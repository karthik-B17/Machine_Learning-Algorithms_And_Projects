# %% [markdown]
# # ANOVA-Analysis Of Variance

# %%
import pandas as pd
import seaborn as sns
tips=sns.load_dataset("tips")

# %%
uniq_days=tips['day'].unique()
uniq_days
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
import pandas as pd
from scipy import stats

# %%
groups=[tips[tips["day"] == d]["total_bill"] for d in tips["day"] . unique()]
groups [0]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 186    20.90
# 187    30.46
# 188    18.15
# 189    23.10
# 190    15.69
# Name: total_bill, Length: 76, dtype: float64

# %%
a_value,P_value=stats.f_oneway(groups[0],groups[1],groups[2],groups[3])

# %%
a_value
# Out:
# np.float64(2.7674794432863363)

# %%
P_value
# Out:
# np.float64(0.04245383328951916)

# %%
tips.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
