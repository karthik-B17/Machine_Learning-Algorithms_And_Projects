# %% [markdown]
# ## Uniform Distribution
# - it is a type of distribution in which all outcomes are equally likely within a certain range.
# - it is characterised by equal probabilities for all the outcome within a specified range[a,b].
# - Random sampling,fairness modelling etc.
# - Two types of uniform distribution
#
# The **uniform distribution** is characterized by equal probabilities for all outcomes within a specified range [a, b]. It is used for random sampling, fairness modeling, and simulations. There are two types:
# 1. **Discrete Uniform Distribution:** Each value in a finite set has equal probability.
# 2. **Continuous Uniform Distribution:** All values within a continuous interval [a, b] are equally likely.
#
# #### **Key Characteristics**
# 1. **PDF (Probability Density Function):**
#    Continuous case:
#    $$
#    f(x) = \frac{1}{b - a}, \quad \text{for } x \in [a, b]
#    $$
# 2. **CDF (Cumulative Distribution Function):**
#    Continuous case:
#    $$
#    F(x) = \frac{x - a}{b - a}, \quad \text{for } x \in [a, b]
#    $$
# 3. **Mean:** $$\mu = \frac{a + b}{2}$$
# 4. **Variance:** $$\sigma^2 = \frac{(b - a)^2}{12}$$

# %%
from numpy import numpy as np

# loading the iris data

df=sns.load_dataset("iris")
df

# %%
# Simulated range of sepal lengths

a=df["sepal_length"].min()
b=df["sepal_length"].max()

a

# %%
b

# %% [markdown]
# # What is the probability density for sepal length in the unifrom distribution?

# %%
x=np.linspace(a,b,1000)  # range
pdf=uniform.pdf(x,loc=a, scale=b-a)
pdf

# %% [markdown]
# # What is the cumulative probability of the sepal lengths below a given value ex-6?

# %%
cdf=uniform.cdf(6,loc=a,scale=b-a)
cdf


cdf_1=uniform.cdf(x,loc=a,scale=b-a)
cdf_1

# %%
# mean and variance for normal distribution
mean=uniform.mean(loc=a,scale=b-a)
variance=uniform.var(loc=a,scale=b-a)
mean,variance

# %% [markdown]
# # visualising PDF and CDF

# %%
plt.plot(x,pdf,label="PDF",color="Blue")
plt.title("Unifrom distribution PDF (sepal length)")
plt.xlabel("Sepal length")
plt.ylabel("Density")

# %%
plt.plot(x,cdf_1,label="CDF",color="Blue")
plt.title("Uniform distribution CDF (sepal length)")
plt.xlabel("Sepal length")
plt.ylabel("Cumulative Density")
