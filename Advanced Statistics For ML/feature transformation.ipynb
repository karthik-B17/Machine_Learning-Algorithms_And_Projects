# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import boxcox,probplot

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
total_bill=tips["total_bill"]
tip=tips["tip"]

# %% [markdown]
# log(total_bill)
# log(0)

# %%
total_bill_log=np.log(total_bill+1e-5)
log_tip=np.log(tip+1e-5)

# %%
boxcox_total_bill,lambda_total_bill=boxcox(total_bill)
boxcox_tip,lambda_tip=boxcox(tip)

# %%
# plotting the graph before transformation:

fig,axes=plt.subplots(2,3,figsize=(25,8))

# original data:

sns.histplot(total_bill,kde=True,ax=axes[0,0],color="skyblue")
axes [0,0].set_title("Total Bill:Histogram with KDE")

probplot(total_bill_log,dist="norm",plot=axes[0,1])
axes [0,1].set_title("Total Bill:QQ plot")

sns.boxplot(total_bill_log, ax=axes[0,2],color="skyblue")
axes [0,2].set_title("Total Bill:Box plot")

sns.histplot(log_tip,kde=True,ax=axes[1,0],color="skyblue")
axes[1,0].set_title("tip:Histogram with KDE")

probplot(log_tip,dist="norm",plot=axes[1,1])
axes[1,1].set_title("tip:QQ plot")

sns.boxplot(log_tip,ax=axes[1,2],color="skyblue")
axes [1,2].set_title("tip:Box plot")
# Out:
# Text(0.5, 1.0, 'tip:Box plot')

# %%
# plotting the graph before transformation:

fig,axes=plt.subplots(2,3,figsize=(12,8))

# original data:

sns.histplot(total_bill,kde=True,ax=axes[0,0],color="skyblue")
axes [0,0].set_title("Total Bill:Histogram with KDE")

probplot(total_bill,dist="norm",plot=axes[0,1])
axes [0,1].set_title("Total Bill:QQ plot")

sns.boxplot(total_bill, ax=axes[0,2],color="skyblue")
axes [0,2].set_title("Total Bill:Box plot")

I

sns.histplot(tip,kde=True,ax=axes[1,0],color="skyblue")
axes[1,0].set_title("tip:Histogram with KDE")

probplot(tip,dist="norm",plot=axes[1,1])
axes[1,1l.set_title("tip:QQ plot")

sns.boxplot(tip,ax=axes[1,2],color="skyblue")
axes [1,2].set_title("tip:Box plot")
