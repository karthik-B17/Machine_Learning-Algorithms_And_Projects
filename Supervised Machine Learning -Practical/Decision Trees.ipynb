# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import  fetch_openml
housing=fetch_openml(name='house_prices',as_frame=True)
housing.data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
x=pd.DataFrame(housing.data,columns=housing.feature_names)
y=pd.DataFrame(housing.target)

# %%
x.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# Length: 80, dtype: int64

# %%
y.isnull().sum()
# Out:
# SalePrice    0
# dtype: int64

# %%
for i in x.columns:
    print(i,x[i].isnull().sum())
# Out:
# Id 0
# MSSubClass 0
# MSZoning 0
# LotFrontage 259
# LotArea 0
# Street 0
# Alley 1369
# LotShape 0
# LandContour 0
# Utilities 0
# LotConfig 0
# LandSlope 0
# Neighborhood 0
# Condition1 0
# Condition2 0
# BldgType 0
# HouseStyle 0
# OverallQual 0
# OverallCond 0
# YearBuilt 0
# YearRemodAdd 0
# RoofStyle 0
# RoofMatl 0
# Exterior1st 0
# Exterior2nd 0
# MasVnrType 8
# MasVnrArea 8
# ExterQual 0
# ExterCond 0
# Foundation 0
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinSF1 0
# BsmtFinType2 38
# BsmtFinSF2 0
# BsmtUnfSF 0
# TotalBsmtSF 0
# Heating 0
# HeatingQC 0
# CentralAir 0
# Electrical 1
# 1stFlrSF 0
# 2ndFlrSF 0
# LowQualFinSF 0
# GrLivArea 0
# BsmtFullBath 0
# BsmtHalfBath 0
# FullBath 0
# HalfBath 0
# BedroomAbvGr 0
# KitchenAbvGr 0
# KitchenQual 0
# TotRmsAbvGrd 0
# Functional 0
# Fireplaces 0
# FireplaceQu 690
# GarageType 81
# GarageYrBlt 81
# GarageFinish 81
# GarageCars 0
# GarageArea 0
# GarageQual 81
# GarageCond 81
# PavedDrive 0
# ...

# %%
x=x.drop(["LotFrontage","Alley","FireplaceQu","PoolQC","Fence","MiscFeature"],axis=1)
x
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
x.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 74, dtype: int64

# %%
# for the numerical columns.
for i in x.columns:
    if (x[i].isnull().sum() != 0) & ((x[i].dtype == "int")|(x[i].dtype == "float")):
      print(i)
# Out:
# MasVnrArea
# GarageYrBlt

# %%
# for object type
h=[]
for i in x.columns:
   if (x[i].isnull().sum() != 0) & (x[i].dtype == "object"):
      h.append(i)
      print(i)
# Out:
# MasVnrType
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Electrical
# GarageType
# GarageFinish
# GarageQual
# GarageCond

# %%
x["MasVnrArea"].describe()
# Out:
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %%
x["MasVnrArea"]=x["MasVnrArea"].fillna(0)

# %%
x["GarageYrBlt"].describe()
# Out:
# count    1379.000000
# mean     1978.506164
# std        24.689725
# min      1900.000000
# 25%      1961.000000
# 50%      1980.000000
# 75%      2002.000000
# max      2010.000000
# Name: GarageYrBlt, dtype: float64

# %%
x["GarageYrBlt"]=x["GarageYrBlt"].fillna(x["GarageYrBlt"].median())

# %%
h
# Out:
# ['MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
for each in h:
   x[each] = x[each].fillna(x[each].mode()[0])

# %%
x.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 74, dtype: int64

# %%
y
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 1 columns]

# %%
from sklearn.datasets import fetch_california_housing
califonia=fetch_california_housing(as_frame=True)
califonia.data
califonia.target
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(califonia.data,califonia.target,test_size=0.3,random_state=30)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([1.109, 2.83 , 1.713, ..., 2.372, 3.87 , 2.247], shape=(6192,))

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.5842660098383795

# %%
# If i am changing the random state then it should not change the accuracy of the model very far from each other

# %% [markdown]
# # Decision Tree Classifier

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=67)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(max_depth=2)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn import  tree
plt.figure(figsize=[15,16])
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[2] <= 2.45\ngini = 0.663\nsamples = 105\nvalue = [38, 30, 37]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[2] <= 4.95\ngini = 0.495\nsamples = 67\nvalue = [0, 30, 37]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.213\nsamples = 33\nvalue = [0, 29, 4]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.057\nsamples = 34\nvalue = [0, 1, 33]')]

# %%
real_model=DecisionTreeClassifier()
real_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=[15,16])
tree.plot_tree(real_model,filled=True)
# Out:
# [Text(0.4, 0.9, 'x[2] <= 2.45\ngini = 0.663\nsamples = 105\nvalue = [38, 30, 37]'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0]'),
#  Text(0.35, 0.8, 'True  '),
#  Text(0.5, 0.7, 'x[2] <= 4.95\ngini = 0.495\nsamples = 67\nvalue = [0, 30, 37]'),
#  Text(0.45, 0.8, '  False'),
#  Text(0.2, 0.5, 'x[3] <= 1.65\ngini = 0.213\nsamples = 33\nvalue = [0, 29, 4]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 28\nvalue = [0, 28, 0]'),
#  Text(0.3, 0.3, 'x[1] <= 3.1\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5, 'x[2] <= 5.05\ngini = 0.057\nsamples = 34\nvalue = [0, 1, 33]'),
#  Text(0.7, 0.3, 'x[1] <= 2.75\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
# ...

# %%
y_pred_real=real_model.predict(x_test)
y_pred_dep=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,y_pred_dep)
# Out:
# 0.9333333333333333

# %%
accuracy_score(y_test,y_pred_real)
# Out:
# 0.9777777777777777

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_dep))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        12
#   versicolor       0.90      0.95      0.93        20
#    virginica       0.92      0.85      0.88        13
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.93      0.94        45
# weighted avg       0.93      0.93      0.93        45
