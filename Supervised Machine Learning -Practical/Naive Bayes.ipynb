# %% [markdown]
# Naive Bayes (Probability )
# Understanding probability
#
# Random experiment: any experiment for which o/p
# is not certain. ex- Tossing a coin, rolling a dice
#
# Sample Space
#
# - Study af uncertainity

# %%
from pandas import notna
col_names = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship',
'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income']

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\karth\Documents\adult.csv\adult.csv",header=None,names=col_names)
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
# finding all the categorical columns
categorical=[var for var in df.columns if df[var].dtype =="object" or df[var].dtype=="category"]

count=len(categorical)
print(f"There are {count} categorical variables")
print("The categorical variables are:\n", categorical)
# Out:
# There are 9 categorical variables
# The categorical variables are:
#  ['workclass', 'education', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'native_country', 'income']

# %%
categorical
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country',
#  'income']

# %%
df[categorical].head()
# Out:
#            workclass   education       marital_status          occupation  \
# 0          State-gov   Bachelors        Never-married        Adm-clerical
# 1   Self-emp-not-inc   Bachelors   Married-civ-spouse     Exec-managerial
# 2            Private     HS-grad             Divorced   Handlers-cleaners
# 3            Private        11th   Married-civ-spouse   Handlers-cleaners
# 4            Private   Bachelors   Married-civ-spouse      Prof-specialty
#
#      relationship    race      sex  native_country  income
# 0   Not-in-family   White     Male   United-States   <=50K
# 1         Husband   White     Male   United-States   <=50K
# 2   Not-in-family   White     Male   United-States   <=50K
# 3         Husband   Black     Male   United-States   <=50K
# 4            Wife   Black   Female            Cuba   <=50K

# %%
# percentage frequency distribution:

for var in categorical:
   print((df[var].value_counts()/len(df))*100)
# Out:
# workclass
# Private             69.703019
# Self-emp-not-inc     7.803814
# Local-gov            6.427935
# ?                    5.638647
# State-gov            3.986364
# Self-emp-inc         3.427413
# Federal-gov          2.948312
# Without-pay          0.042996
# Never-worked         0.021498
# Name: count, dtype: float64
# education
# HS-grad         32.250238
# Some-college    22.391818
# Bachelors       16.446055
# Masters          5.291607
# Assoc-voc        4.244341
# 11th             3.608612
# Assoc-acdm       3.276926
# 10th             2.865391
# 7th-8th          1.983969
# Prof-school      1.768987
# 9th              1.578576
# 12th             1.329812
# Doctorate        1.268389
# 5th-6th          1.022696
# 1st-4th          0.515955
# Preschool        0.156629
# Name: count, dtype: float64
# marital_status
# Married-civ-spouse       45.993673
# Never-married            32.809189
# Divorced                 13.645158
# Separated                 3.147938
# ...

# %%
import numpy as np

# %%
df.workclass=df.workclass.str.strip()

# %%
df.workclass.replace({"?":np.nan},inplace=True)
df.workclass.value_counts()
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_19248\3226314496.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.workclass.replace({"?":np.nan},inplace=True)
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
df.occupation = df.occupation.str.strip()
df.occupation.replace({"?": np.nan}, inplace=True)
df.occupation.value_counts()
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_19248\3276383426.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.occupation.replace({"?": np.nan}, inplace=True)
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# ...

# %%
df.native_country = df.native_country.str.strip()
df.native_country.replace({"?": np.nan}, inplace=True)
df.native_country.value_counts()
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_19248\2963897521.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.native_country.replace({"?": np.nan}, inplace=True)
# native_country
# United-States                 29170
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# ...

# %%
df.workclass.fillna(df.workclass.mode()[0],inplace=True)
df.native_country.fillna(df.native_country.mode()[0],inplace=True)
df.workclass.fillna(df.workclass.mode()[0],inplace=True)
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_19248\4187793173.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.workclass.fillna(df.workclass.mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# income               0
# dtype: int64

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
numerical=[col for col in df.columns if df[col].dtypes=="int64"]
numerical
# Out:
# ['age',
#  'fnlwgt',
#  'education_num',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_week']

# %%
df[numerical].isnull().sum()
# Out:
# age               0
# fnlwgt            0
# education_num     0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# dtype: int64

# %%
# seperate input and output target features

x=df.drop("income",axis=1)
y=df["income"]
print(x,y)
# Out:
#        age         workclass  fnlwgt    education  education_num  \
# 0       39         State-gov   77516    Bachelors             13
# 1       50  Self-emp-not-inc   83311    Bachelors             13
# 2       38           Private  215646      HS-grad              9
# 3       53           Private  234721         11th              7
# 4       28           Private  338409    Bachelors             13
# ...    ...               ...     ...          ...            ...
# 32556   27           Private  257302   Assoc-acdm             12
# 32557   40           Private  154374      HS-grad              9
# 32558   58           Private  151910      HS-grad              9
# 32559   22           Private  201490      HS-grad              9
# 32560   52      Self-emp-inc  287927      HS-grad              9
#
#             marital_status         occupation    relationship    race  \
# 0            Never-married       Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# # splitting the training and testing data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=20)

# %%
x_train.shape
# Out:
# (22792, 14)

# %%
x_test.shape
# Out:
# (9769, 14)

# %% [markdown]
# # encoding the categorical features

# %%
# !pip install category_encoders
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
categorical_test=categorical[:len(categorical)-1]
categorical_test
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country']

# %%
import category_encoders as ce

# %%
encoders=ce.OneHotEncoder(cols=['workclass',
 'education',
 'marital_status',
 'occupation',
 'relationship',
 'race',
 'sex',
 'native_country'])
x_train_cat=encoders.fit_transform(x_train[categorical_test])
x_test_cat=encoders.transform(x_test[categorical_test])

# %%
x_train_cat
# Out:
#        workclass_1  workclass_2  workclass_3  workclass_4  workclass_5  \
# 14878            1            0            0            0            0
# 18249            1            0            0            0            0
# 24236            1            0            0            0            0
# 19022            0            1            0            0            0
# 8947             1            0            0            0            0
# ...            ...          ...          ...          ...          ...
# 23452            0            0            0            0            1
# 23775            0            0            1            0            0
# 4367             1            0            0            0            0
# 27098            1            0            0            0            0
# 15715            1            0            0            0            0
#
#        workclass_6  workclass_7  workclass_8  education_1  education_2  ...  \
# ...

# %%
x_test
# Out:
#        age         workclass  fnlwgt      education  education_num  \
# 13376   34           Private  105493        Masters             14
# 7676    40           Private  235786   Some-college             10
# 32188   29           Private  153416      Bachelors             13
# 30550   43  Self-emp-not-inc  118261        Masters             14
# 18873   27           Private  244402     Assoc-acdm             12
# ...    ...               ...     ...            ...            ...
# 2097    56         Local-gov  160829        HS-grad              9
# 15547   32           Private  251612        5th-6th              3
# 31937   22           Private  239954   Some-college             10
# 6225    36           Private  383518   Some-college             10
# 19227   28           Private  190836        HS-grad              9
#
#             marital_status       occupation     relationship    race      sex  \
# 13376             Divorced   Prof-specialty        Unmarried   White   Female
# ...

# %%
numerical
# Out:
# ['age',
#  'fnlwgt',
#  'education_num',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_week']

# %%
# feature scaling

from sklearn.preprocessing import RobustScaler
scaler=RobustScaler()
x_train_num=scaler.fit_transform(x_train[numerical])
x_test_num=scaler.transform(x_test[numerical])
x_train_num=pd.DataFrame(x_train_num,columns=numerical,index=x_train[numerical].index)
x_test_num=pd.DataFrame(x_test_num,columns=numerical,index=x_test[numerical].index)
x_train_cat=pd.DataFrame(x_train_cat)
x_test_cat=pd.DataFrame(x_test_cat)

# %%
x_train_cat
# Out:
#        workclass_1  workclass_2  workclass_3  workclass_4  workclass_5  \
# 14878            1            0            0            0            0
# 18249            1            0            0            0            0
# 24236            1            0            0            0            0
# 19022            0            1            0            0            0
# 8947             1            0            0            0            0
# ...            ...          ...          ...          ...          ...
# 23452            0            0            0            0            1
# 23775            0            0            1            0            0
# 4367             1            0            0            0            0
# 27098            1            0            0            0            0
# 15715            1            0            0            0            0
#
#        workclass_6  workclass_7  workclass_8  education_1  education_2  ...  \
# ...

# %%
x_train_res=pd.concat([x_train_num,x_train_cat],axis=1)

# %%
x_test_res=pd.concat([x_test_num,x_test_cat],axis=1)
x_test_res
# Out:
#         age    fnlwgt  education_num  capital_gain  capital_loss  \
# 13376 -0.15 -0.613155       1.333333           0.0           0.0
# 7676   0.15  0.483818       0.000000           0.0           0.0
# 32188 -0.40 -0.209678       1.000000           0.0           0.0
# 30550  0.30 -0.505658       1.333333           0.0           0.0
# 18873 -0.50  0.556359       0.666667           0.0           0.0
# ...     ...       ...            ...           ...           ...
# 2097   0.95 -0.147266      -0.333333           0.0           0.0
# 15547 -0.25  0.617062      -2.333333           0.0           0.0
# 31937 -0.75  0.518910       0.000000           0.0           0.0
# 6225  -0.05  1.727615       0.000000       99999.0           0.0
# 19227 -0.45  0.105372      -0.333333        3411.0           0.0
#
#        hours_per_week  workclass_1  workclass_2  workclass_3  workclass_4  \
# 13376             0.0            1            0            0            0
# ...

# %%
x_train_res.shape
# Out:
# (22792, 106)

# %%
x_test_res.shape
# Out:
# (9769, 106)

# %%
x_train_res.isnull().sum()
# Out:
# age                  0
# fnlwgt               0
# education_num        0
# capital_gain         0
# capital_loss         0
#                     ..
# native_country_37    0
# native_country_38    0
# native_country_39    0
# native_country_40    0
# native_country_41    0
# Length: 106, dtype: int64

# %%
x_train_res.shape
# Out:
# (22792, 106)

# %%
x_test.shape
# Out:
# (9769, 14)

# %%
x_test_res.shape
# Out:
# (9769, 106)

# %% [markdown]
# # training the model

# %% [markdown]
# ## Gaussian NB Classifier

# %%
from sklearn.naive_bayes import GaussianNB
# instance of the class
model=GaussianNB()
model.fit(x_train_res,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# If we end up the columns as these then we may have to rename those tuples
#
# like ('age',)
#
# x_train.rename(columns={"('age',)":"age"})....
#
# or alternativeley you can say x_train=x_train.values

# %%
x_train_res
# Out:
#         age    fnlwgt  education_num  capital_gain  capital_loss  \
# 14878 -0.30  0.472991       1.000000           0.0           0.0
# 18249 -0.40 -0.151896      -0.333333           0.0           0.0
# 24236  0.00 -1.083515       0.333333           0.0           0.0
# 19022  0.00  0.536119       1.000000           0.0           0.0
# 8947   0.95  0.579234      -2.000000           0.0           0.0
# ...     ...       ...            ...           ...           ...
# 23452  0.60  0.429851      -0.333333           0.0           0.0
# 23775 -0.30  0.349926      -0.333333           0.0           0.0
# 4367  -0.20  0.655782      -0.333333           0.0           0.0
# 27098 -0.40  0.020522       0.666667           0.0           0.0
# 15715  0.05  4.378383      -0.333333           0.0           0.0
#
#        hours_per_week  workclass_1  workclass_2  workclass_3  workclass_4  \
# 14878             0.0            1            0            0            0
# ...

# %%
# predict the results
y_pred=model.predict(x_test_res)
y_pred=pd.DataFrame(y_pred)
y_pred
# Out:
#            0
# 0      <=50K
# 1       >50K
# 2      <=50K
# 3      <=50K
# 4      <=50K
# ...      ...
# 9764   <=50K
# 9765   <=50K
# 9766   <=50K
# 9767    >50K
# 9768    >50K
#
# [9769 rows x 1 columns]

# %%
y_test
# Out:
# 13376     <=50K
# 7676       >50K
# 32188     <=50K
# 30550     <=50K
# 18873      >50K
#           ...
# 2097      <=50K
# 15547     <=50K
# 31937     <=50K
# 6225       >50K
# 19227     <=50K
# Name: income, Length: 9769, dtype: object

# %%
from sklearn.metrics import accuracy_score, classification_report

accuracy_score(y_test,y_pred)
# Out:
# 0.8021291841539564

# %%
# creating a confusion matrix

from sklearn.metrics import confusion_matrix,classification_report
confusion_matrix(y_test,y_pred)
# Out:
# array([[5892, 1486],
#        [ 447, 1944]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.93      0.80      0.86      7378
#         >50K       0.57      0.81      0.67      2391
#
#     accuracy                           0.80      9769
#    macro avg       0.75      0.81      0.76      9769
# weighted avg       0.84      0.80      0.81      9769

# %% [markdown]
# precision results in minimising the false positive
#
#
# recall results in minimising the false negative

# %% [markdown]
# if the model has very low recall for the minority class then the f1 score will be low
